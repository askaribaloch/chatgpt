# %%
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

_ : bool = load_dotenv(find_dotenv()) # read local .env file

client : OpenAI = OpenAI()

# %%
stream = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[{"role": "user", "content": "how is considered founder of programming language?"}],
    stream=True,
)
for part in stream:
    print(part.choices[0].delta.content or "")
# Out:
# The
#  founding
#  of
#  a
#  programming
#  language
#  is
#  typically
#  attributed
#  to
#  the
#  individual
#  or
#  group
#  of
#  individuals
#  who
#  designed
#  and
#  developed
#  the
#  language
# .
#  This
#  involves
#  creating
#  the
#  syntax
# ,
#  rules
# ,
#  and
#  specifications
#  for
#  the
#  language
# ,
#  as
#  well
#  as
#  writing
#  the
#  initial
#  compiler
#  or
#  interpreter
# .
#  The
#  founder
#  or
#  founders
#  of
#  a
#  programming
#  language
#  are
#  generally
#  credited
#  with
#  the
#  original
#  conceptual
# ization
#  and
#  implementation
#  of
#  the
#  language
# .
#  This
#  can
#  be
#  a
#  single
#  person
# ,
#  such
#  as
#  Dennis
#  Ritch
# ie
#  with
#  C
# ,
#  or
#  a
#  team
#  of
#  people
# ,
#  such
#  as
#  the
#  group
#  that
#  developed
#  the
#  Python
#  programming
#  language
# .
